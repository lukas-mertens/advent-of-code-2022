# %% [markdown]
# # Day 7
#
# Link to challenge: https://adventofcode.com/2022/day/7
#
# ## Part 1
#
# In this challenge we have to build a file tree from our puzzle input.

# %%
from anytree import Node, RenderTree, PreOrderIter
from typing import List
import re

root: Node = Node("/")
pwd: Node  = root

def parse_input(lines: List[str]):
    for line in lines:
        if line.startswith("$ cd "):
            execute_cd(line)
        elif line.startswith("dir "):
            append_dir_from_ls_result(line)
        elif is_file_line(line):
            append_file_from_ls_result(line)
            
def is_file_line(line: str):
    return re.match("\d.*", line)

def render_tree(tree):
    for pre, fill, node in RenderTree(tree):
        print("%s%s" % (pre, node.name))

def append_dir_from_ls_result(line: str):
    dirname = line.strip().split(" ")[1]
    dirnode = Node("d_" + dirname)
    dirnode.parent = pwd

def append_file_from_ls_result(line: str):
    filesize, filename = line.strip().split(" ")
    filenode = Node("f_" + str(filesize) + "_" + filename)
    filenode.parent = pwd

def get_node_size(node: Node): 
    if str(node.name).startswith("f_"):
        return int(str(node.name).split("_")[1])
    else:
        return sum(map(get_node_size, node.children))


def execute_cd(line: str):
    arg1 = line.strip().split(" ")[2]
    global pwd
    if arg1 == "/":
        pwd = root
    elif arg1 == "..":
        pwd = pwd.parent
    else :
        map(lambda c: c.name, pwd.children)
        for c in pwd.children:
            if c.name == "d_" + arg1:
                pwd = c
                return

# this implementation has a really bad asymptotic runtime complexity. For better runtime we could build a tree of sizes and work on that to prevent calculating the same thing multiple times
def sum_of_directories_smaller_than_x(root, x):
    return sum(filter(lambda size: size <= x, [get_node_size(node) for node in PreOrderIter(root) if str(node.name).startswith("d_")]))

# this implementation has a really bad asymptotic runtime complexity. For better runtime we could build a tree of sizes and work on that to prevent calculating the same thing multiple times
def smallest_directoy_larger_than_x(root, x):
    return min(filter(lambda size: size >= x, [get_node_size(node) for node in PreOrderIter(root) if str(node.name).startswith("d_")]))

# %%
with open("puzzle-input/7.txt", "r") as f:
    parse_input(list(map(str, f.readlines())))
    render_tree(root)
    print("Part 1", sum_of_directories_smaller_than_x(root, 100000))
    print("Part 2", smallest_directoy_larger_than_x(root, 30000000-(70000000-get_node_size(root))))
# Out:
# /
# ├── d_fnsvfbzt
# │   └── f_62158_sfwnts.hbj
# ├── d_hqdssf
# │   ├── f_45626_cvcbmcm
# │   ├── d_dlsmjsbz
# │   │   └── f_9205_qcqbgd.lzd
# │   ├── d_hqdssf
# │   │   ├── f_105963_mhqs.zrn
# │   │   └── f_87909_slwshm.nwr
# │   ├── d_mhqs
# │   │   ├── d_ctfl
# │   │   │   └── d_shzgg
# │   │   │       ├── f_18097_cvcbmcm
# │   │   │       ├── f_289064_mhqs
# │   │   │       ├── f_208557_slwshm.nwr
# │   │   │       ├── f_283449_vjw
# │   │   │       └── d_wfbvtfmr
# │   │   │           ├── f_263560_dssbpgnl.szh
# │   │   │           ├── d_hnqjmq
# │   │   │           │   └── f_3307_rjd.lgh
# │   │   │           ├── f_76551_jvvl.rcs
# │   │   │           ├── f_195911_lncqsmj
# │   │   │           └── f_185776_slwshm.nwr
# │   │   ├── f_45923_jvvl.rcs
# │   │   ├── d_jzjm
# │   │   │   └── f_31719_rjjrg.pjq
# │   │   ├── d_lncqsmj
# │   │   │   └── d_mhqs
# │   │   │       └── f_138296_wfbvtfmr
# │   │   ├── d_mhqs
# │   │   │   ├── f_175499_jvvl.rcs
# │   │   │   ├── d_rqznrr
# │   │   │   │   └── f_105075_shslmlt.spg
# │   │   │   ├── f_108476_slwshm.nwr
# │   │   │   └── f_199853_vjw
# │   │   └── d_wfbvtfmr
# │   │       └── f_131522_rjjrg.pjq
# │   ├── d_mtw
# │   │   ├── d_dcgpfrsf
# │   │   │   ├── f_47863_dfwthflp.jwq
# │   │   │   ├── f_203815_dqbqbps.prq
# │   │   │   ├── d_mhqs
# │   │   │   │   └── f_74450_tjpn
# │   │   │   ├── f_183653_rqjqpm.bbr
# │   │   │   └── f_220694_vjw
# │   │   ├── d_gwqm
# │   │   │   └── d_trghjhvs
# │   │   │       ├── d_shzgg
# │   │   │       │   └── f_73435_shzgg.bbf
# │   │   │       └── f_2620_slwshm.nwr
# │   │   ├── f_188911_hqdssf
# │   │   ├── f_34693_jvvl.rcs
# │   │   └── d_shzgg
# │   │       └── f_184378_rjjrg.pjq
# │   ├── d_sfccfsrd
# │   │   ├── f_87317_ccvs.phq
# │   │   ├── d_cqmgf
# │   │   │   └── f_202804_tcrqqlgs
# │   │   ├── d_cssmfv
# │   │   │   └── f_13440_jnhzrtfd
# │   │   ├── d_hhhqdmz
# │   │   │   ├── d_fdbpld
# │   │   │   │   ├── d_bgrnz
# │   │   │   │   │   ├── d_qzs
# │   │   │   │   │   │   └── f_156779_lncqsmj.gnf
# │   │   │   │   │   ├── d_rcv
# │   │   │   │   │   │   ├── f_224927_dvbw.svf
# │   │   │   │   │   │   ├── d_hqdssf
# │   │   │   │   │   │   │   ├── f_63099_blpdwd
# │   │   │   │   │   │   │   ├── f_96035_jvvl.rcs
# │   │   │   │   │   │   │   ├── f_40533_lvpsmzw
# │   │   │   │   │   │   │   ├── f_205031_rjjrg.pjq
# │   │   │   │   │   │   │   ├── f_59874_shzgg.ldg
# │   │   │   │   │   │   │   └── d_zdnfpwlw
# │   │   │   │   │   │   │       ├── f_109325_hqdssf.fmj
# │   │   │   │   │   │   │       ├── f_41775_jfqhq.tdn
# │   │   │   │   │   │   │       ├── f_203744_nprghch.zjb
# │   │   │   │   │   │   │       ├── d_qfs
# │   │   │   │   │   │   │       │   └── f_234449_vjw
# │   │   │   │   │   │   │       ├── d_rzctqrgm
# │   │   │   │   │   │   │       │   └── f_99041_cvcbmcm
# │   │   │   │   │   │   │       └── d_shzgg
# │   │   │   │   │   │   │           ├── f_149752_mhqs.bds
# │   │   │   │   │   │   │           ├── f_126331_rjjrg.pjq
# │   │   │   │   │   │   │           └── f_75464_vbcjqdjv
# │   │   │   │   │   │   ├── d_jjmsqft
# │   │   │   │   │   │   │   └── f_47522_shzgg
# │   │   │   │   │   │   ├── f_255189_mhqs.pcl
# │   │   │   │   │   │   ├── d_mvgqtlm
# │   │   │   │   │   │   │   ├── d_tgtbj
# │   │   │   │   │   │   │   │   ├── f_86585_lbmv.jcr
# │   │   │   │   │   │   │   │   └── f_202755_rjjrg.pjq
# │   │   │   │   │   │   │   ├── d_tmrsn
# │   │   │   │   │   │   │   │   └── f_150980_hqdssf.hmh
# │   │   │   │   │   │   │   └── d_vpv
# │   │   │   │   │   │   │       └── f_197783_jvvl.rcs
# │   │   │   │   │   │   ├── d_pjs
# │   │   │   │   │   │   │   ├── f_216539_cvcbmcm
# │   │   │   │   │   │   │   ├── f_159509_jgfphj
# │   │   │   │   │   │   │   ├── f_195297_pdgnb.qjd
# │   │   │   │   │   │   │   └── f_162974_rjjrg.pjq
# │   │   │   │   │   │   └── d_sljw
# │   │   │   │   │   │       └── f_61689_hqdssf.bbn
# │   │   │   │   │   └── d_wmrmhdd
# │   │   │   │   │       └── f_92888_msgcqfbf
# │   │   │   │   ├── d_dcdj
# │   │   │   │   │   └── f_99280_mclcnw
# │   │   │   │   ├── f_78284_jqqfc.tzz
# │   │   │   │   ├── f_147731_lbdsh.plp
# │   │   │   │   └── f_269235_ntf.gmq
# │   │   │   ├── f_272827_jftd.lml
# │   │   │   ├── d_prqbhbv
# │   │   │   │   ├── f_102589_bqlcds.pqp
# │   │   │   │   ├── f_107625_mhqs
# │   │   │   │   └── f_281871_mvwvdtd.dzf
# │   │   │   └── d_wbzvmz
# │   │   │       └── f_287371_tnwgfw
# │   │   ├── f_17971_mhqs
# │   │   ├── d_mvjttqr
# │   │   │   ├── d_dtf
# │   │   │   │   ├── f_121764_cvcbmcm
# │   │   │   │   ├── f_279094_lncqsmj
# │   │   │   │   ├── f_68484_slwshm.nwr
# │   │   │   │   └── f_278387_vjw
# │   │   │   ├── d_frcqdb
# │   │   │   │   ├── f_233216_lncqsmj.mbd
# │   │   │   │   └── f_217901_slwshm.nwr
# │   │   │   ├── d_hqdssf
# │   │   │   │   ├── d_dgdtm
# │   │   │   │   │   ├── d_cnshbf
# │   │   │   │   │   │   ├── f_72788_hqdssf.mhc
# │   │   │   │   │   │   └── f_122945_rjjrg.pjq
# │   │   │   │   │   └── f_173312_vjw
# │   │   │   │   ├── f_260973_qnt
# │   │   │   │   ├── f_231311_thdrddd.zmj
# │   │   │   │   ├── f_160399_vjw
# │   │   │   │   ├── d_vpqjmmf
# │   │   │   │   │   ├── f_127969_hqdssf.stc
# │   │   │   │   │   ├── f_267724_lncqsmj
# │   │   │   │   │   ├── f_55890_mhqs.mql
# │   │   │   │   │   └── d_tsbtz
# │   │   │   │   │       ├── f_244065_qqfnbd.nqv
# │   │   │   │   │       └── f_59649_qttbcgd.vtj
# │   │   │   │   └── f_197241_vqvzsv.nzg
# │   │   │   ├── f_55645_slwshm.nwr
# │   │   │   └── d_zdzchmtq
# │   │   │       ├── f_271886_lmphsmv
# │   │   │       └── d_nncghrr
# │   │   │           └── f_180468_rjjrg.pjq
# │   │   ├── f_264394_slwshm.nwr
# │   │   ├── d_stdzptb
# │   │   │   └── f_19398_frsztqqz.mnc
# │   │   ├── d_tcddd
# │   │   │   ├── d_hqdssf
# │   │   │   │   └── f_178907_gcslqrn
# │   │   │   ├── f_71084_jvvl.rcs
# │   │   │   └── d_wnzhld
# │   │   │       └── f_206073_hpdnj
# │   │   ├── d_zmrt
# │   │   │   ├── d_bmfgjr
# │   │   │   │   └── f_189592_jhmgm
# │   │   │   ├── d_bpztq
# │   │   │   │   └── f_184906_rjjrg.pjq
# │   │   │   ├── d_chsh
# │   │   │   │   ├── f_110753_jvvl.rcs
# │   │   │   │   ├── d_lncqsmj
# │   │   │   │   │   └── d_pzd
# │   │   │   │   │       └── f_287833_vhfjdg.jrz
# │   │   │   │   ├── d_njdgplj
# │   │   │   │   │   ├── d_cbvz
# │   │   │   │   │   │   └── d_rtpcsrf
# │   │   │   │   │   │       └── f_240018_wfbvtfmr
# │   │   │   │   │   └── d_vfhj
# │   │   │   │   │       ├── f_152840_cbbrgc.wnq
# │   │   │   │   │       ├── f_243656_hqdssf
# │   │   │   │   │       └── f_36325_hqdssf.fhn
# │   │   │   │   ├── d_qhpplfnd
# │   │   │   │   │   └── f_206490_dfththnq.vnm
# │   │   │   │   ├── f_190460_rjjrg.pjq
# │   │   │   │   └── f_144668_wfbvtfmr.flv
# │   │   │   ├── d_dpjhn
# │   │   │   │   ├── f_127322_rjjrg.pjq
# │   │   │   │   └── d_shzgg
# │   │   │   │       └── f_165774_cvcbmcm
# │   │   │   └── f_288144_mhqs.zvb
# │   │   └── d_zqqtb
# │   │       ├── d_ljnmbqvd
# │   │       │   ├── f_268048_bdbjn
# │   │       │   ├── d_fjh
# │   │       │   │   └── f_180021_hqdssf.rqs
# │   │       │   ├── d_qpclpbz
# │   │       │   │   ├── f_109952_blmm.nsv
# │   │       │   │   ├── d_dltbt
# │   │       │   │   │   ├── f_205121_dfzlcv.hjf
# │   │       │   │   │   ├── f_56409_hpqhhmb.sss
# │   │       │   │   │   ├── f_233277_hqdssf.qcb
# │   │       │   │   │   ├── f_187838_mbmcfhf.fnj
# │   │       │   │   │   ├── d_rrqjn
# │   │       │   │   │   │   └── f_240447_lncqsmj
# │   │       │   │   │   ├── d_swrgj
# │   │       │   │   │   │   ├── d_lnnwdbt
# │   │       │   │   │   │   │   └── f_213111_tnn.bhq
# │   │       │   │   │   │   ├── d_sgjsn
# │   │       │   │   │   │   │   └── d_wpprqhs
# │   │       │   │   │   │   │       └── d_hqdssf
# │   │       │   │   │   │   │           └── f_209286_qbdfzdzw.sgp
# │   │       │   │   │   │   └── d_wfbvtfmr
# │   │       │   │   │   │       ├── f_199298_hqdssf.chs
# │   │       │   │   │   │       └── f_123953_rjjrg.pjq
# │   │       │   │   │   └── f_151306_tqjzq.dmg
# │   │       │   │   ├── d_htbzp
# │   │       │   │   │   ├── d_bmfr
# │   │       │   │   │   │   └── f_19937_shzgg
# │   │       │   │   │   ├── f_68162_bzwcswr.mlv
# │   │       │   │   │   ├── f_284074_dtzwf
# │   │       │   │   │   ├── f_270421_jpsvh.ncc
# │   │       │   │   │   ├── d_mwbvz
# │   │       │   │   │   │   └── f_156668_rjjrg.pjq
# │   │       │   │   │   ├── f_95631_shzgg.tbf
# │   │       │   │   │   └── f_44434_vjw
# │   │       │   │   ├── f_287761_mfbd
# │   │       │   │   ├── d_mhqs
# │   │       │   │   │   ├── f_111821_ftrv.zcw
# │   │       │   │   │   ├── d_jsnlcn
# │   │       │   │   │   │   ├── f_7527_smqts.cnc
# │   │       │   │   │   │   └── d_svdw
# │   │       │   │   │   │       └── f_173846_vjtrp
# │   │       │   │   │   ├── d_mhqs
# │   │       │   │   │   │   ├── d_hswdjgg
# │   │       │   │   │   │   │   └── f_285037_jvvl.rcs
# │   │       │   │   │   │   └── f_30326_rjjrg.pjq
# │   │       │   │   │   ├── d_rjdwmb
# │   │       │   │   │   │   └── f_219498_twl.lmw
# │   │       │   │   │   └── d_sfmrwgd
# │   │       │   │   │       └── f_168290_ltwpm.fjl
# │   │       │   │   ├── d_vgbvrwvn
# │   │       │   │   │   ├── d_bswv
# │   │       │   │   │   │   ├── f_121032_cncdt
# │   │       │   │   │   │   ├── d_jrbmlg
# │   │       │   │   │   │   │   └── f_37975_shzgg.bnq
# │   │       │   │   │   │   ├── d_lncqsmj
# │   │       │   │   │   │   │   ├── f_114558_jvvl.rcs
# │   │       │   │   │   │   │   ├── d_mhqs
# │   │       │   │   │   │   │   │   └── d_wpnw
# │   │       │   │   │   │   │   │       └── f_286077_lncqsmj.cld
# │   │       │   │   │   │   │   ├── d_nfn
# │   │       │   │   │   │   │   │   ├── f_269740_cvcbmcm
# │   │       │   │   │   │   │   │   ├── f_87123_mhqs.nst
# │   │       │   │   │   │   │   │   ├── f_61029_mhqs.vhb
# │   │       │   │   │   │   │   │   └── f_211712_slwshm.nwr
# │   │       │   │   │   │   │   ├── d_nhlbfq
# │   │       │   │   │   │   │   │   └── f_247458_lncqsmj
# │   │       │   │   │   │   │   ├── f_141816_phtt.phj
# │   │       │   │   │   │   │   ├── f_181530_vjw
# │   │       │   │   │   │   │   └── f_224510_zmzp.jwg
# │   │       │   │   │   │   ├── d_mhmgn
# │   │       │   │   │   │   │   └── f_85806_vjw
# │   │       │   │   │   │   ├── f_65380_rjjrg.pjq
# │   │       │   │   │   │   └── d_wfbvtfmr
# │   │       │   │   │   │       ├── f_275888_cvvhvg.pwv
# │   │       │   │   │   │       ├── f_151703_gnbm
# │   │       │   │   │   │       ├── f_61419_grcfbwdp
# │   │       │   │   │   │       ├── f_150382_gzdmzj.wpc
# │   │       │   │   │   │       ├── d_mtrqcwrd
# │   │       │   │   │   │       │   └── f_273564_shzgg.tbm
# │   │       │   │   │   │       └── f_112827_nbtjlnt.srg
# │   │       │   │   │   ├── d_hqdssf
# │   │       │   │   │   │   ├── f_72227_ccvwdrs.dsf
# │   │       │   │   │   │   ├── f_141028_dctbz.spr
# │   │       │   │   │   │   ├── d_shzgg
# │   │       │   │   │   │   │   ├── f_143437_lncqsmj.vpl
# │   │       │   │   │   │   │   ├── f_78418_pbdwbmtd.nlp
# │   │       │   │   │   │   │   └── f_28173_vlfj.tps
# │   │       │   │   │   │   ├── f_277461_slwshm.nwr
# │   │       │   │   │   │   ├── f_94390_stgp.trm
# │   │       │   │   │   │   └── f_24297_vgdzsrrl.dhg
# │   │       │   │   │   └── d_mhqs
# │   │       │   │   │       ├── f_97312_jvvl.rcs
# │   │       │   │   │       ├── d_qqfbsz
# │   │       │   │   │       │   ├── d_lncqsmj
# │   │       │   │   │       │   │   └── f_186873_wfbvtfmr.lfh
# │   │       │   │   │       │   └── d_mhqs
# │   │       │   │   │       │       └── d_wfbvtfmr
# │   │       │   │   │       │           └── f_234441_gsjwsn
# │   │       │   │   │       ├── f_42472_rjjrg.pjq
# │   │       │   │   │       └── d_wfbvtfmr
# │   │       │   │   │           ├── f_55214_dgf
# │   │       │   │   │           ├── d_fdtz
# │   │       │   │   │           │   └── d_rdzsjm
# │   │       │   │   │           │       └── d_mjgfpvc
# │   │       │   │   │           │           └── d_vfcq
# │   │       │   │   │           │               └── d_fmtfm
# │   │       │   │   │           │                   └── f_200137_dvbqjq
# │   │       │   │   │           ├── f_6756_jvvl.rcs
# │   │       │   │   │           ├── f_226995_rpsjvr.wpb
# │   │       │   │   │           └── f_68993_vjw
# │   │       │   │   └── d_wmhd
# │   │       │   │       ├── d_hnn
# │   │       │   │       │   ├── f_16335_wfbvtfmr.vhw
# │   │       │   │       │   └── f_262909_zgtln.dwc
# │   │       │   │       └── d_rzt
# │   │       │   │           ├── f_285086_mhqs.vsg
# │   │       │   │           └── d_qnr
# │   │       │   │               └── f_290611_llnp.hsh
# │   │       │   ├── d_rqpljw
# │   │       │   │   └── f_267152_jbv
# │   │       │   ├── d_tzjftf
# │   │       │   │   ├── f_258707_cnfb.dgv
# │   │       │   │   ├── f_17087_hqdssf.dtd
# │   │       │   │   ├── f_92075_nwvtww
# │   │       │   │   ├── d_qblrnn
# │   │       │   │   │   ├── d_brrqp
# │   │       │   │   │   │   └── f_270783_wfbvtfmr
# │   │       │   │   │   ├── d_frqcc
# │   │       │   │   │   │   ├── d_clj
# │   │       │   │   │   │   │   └── f_31407_grm.pwv
# │   │       │   │   │   │   ├── f_7502_lncqsmj
# │   │       │   │   │   │   ├── d_mnsbr
# │   │       │   │   │   │   │   ├── d_wfbvtfmr
# │   │       │   │   │   │   │   │   └── f_81283_cvcbmcm
# │   │       │   │   │   │   │   └── f_99467_whsrtf.gff
# │   │       │   │   │   │   ├── f_73859_scwltjwh.cqd
# │   │       │   │   │   │   ├── f_29920_vjw
# │   │       │   │   │   │   └── d_wpplgrc
# │   │       │   │   │   │       └── f_285496_lncqsmj.hwq
# │   │       │   │   │   ├── f_25504_jvvl.rcs
# │   │       │   │   │   ├── d_lncqsmj
# │   │       │   │   │   │   └── f_8972_jvvl.rcs
# │   │       │   │   │   ├── d_mhqs
# │   │       │   │   │   │   └── f_119520_hqdssf.tbn
# │   │       │   │   │   ├── f_107908_rjjrg.pjq
# │   │       │   │   │   ├── f_286918_rngbhp.ntg
# │   │       │   │   │   ├── d_shzgg
# │   │       │   │   │   │   ├── f_180825_lncqsmj.rsg
# │   │       │   │   │   │   └── f_23507_wfbvtfmr
# │   │       │   │   │   ├── d_wcnh
# │   │       │   │   │   │   ├── f_98662_tmwrh
# │   │       │   │   │   │   └── f_220468_wml.sht
# │   │       │   │   │   └── d_wfbvtfmr
# │   │       │   │   │       └── f_283178_hqdssf.ctf
# │   │       │   │   └── d_tdg
# │   │       │   │       ├── f_283636_cvcbmcm
# │   │       │   │       ├── f_117742_gsqzjfn.pmp
# │   │       │   │       ├── f_176660_lncqsmj
# │   │       │   │       ├── d_pbdgbsts
# │   │       │   │       │   └── f_92092_vjw
# │   │       │   │       └── d_znvv
# │   │       │   │           ├── f_41213_hqdssf.rnn
# │   │       │   │           └── d_pcttrtd
# │   │       │   │               └── f_16759_mhqs.gpb
# │   │       │   ├── f_255809_vjw
# │   │       │   └── f_243604_wfbvtfmr.rzb
# │   │       ├── f_60485_pcz.snl
# │   │       ├── f_274930_slwshm.nwr
# │   │       ├── f_131928_vqm
# │   │       └── f_51341_wfbvtfmr.stc
# │   └── d_shzgg
# │       ├── f_19544_bcn.rws
# │       ├── d_fqwpwcq
# │       │   ├── f_269576_mhqs
# │       │   └── d_pmfv
# │       │       ├── f_175725_jvvl.rcs
# │       │       └── f_29161_pnbm.mlr
# │       ├── d_hngpzst
# │       │   ├── f_18430_cvcbmcm
# │       │   ├── d_fgzlgbm
# │       │   │   ├── f_134751_dwlfbfjp
# │       │   │   ├── d_hqdssf
# │       │   │   │   ├── f_87131_bdmdpdf.cqg
# │       │   │   │   ├── d_fdc
# │       │   │   │   │   └── f_116738_cvcbmcm
# │       │   │   │   └── d_gwgp
# │       │   │   │       ├── d_qdvss
# │       │   │   │       │   └── f_111546_wqnsrnh
# │       │   │   │       ├── d_rpwzw
# │       │   │   │       │   ├── f_183614_lfjqvff
# │       │   │   │       │   └── f_129803_rdwd
# │       │   │   │       └── d_wfbvtfmr
# │       │   │   │           ├── f_266779_mhqs
# │       │   │   │           ├── f_189793_slwshm.nwr
# │       │   │   │           ├── f_279894_sncqtvwp.mff
# │       │   │   │           └── f_40520_vjw
# │       │   │   ├── f_227313_jvvl.rcs
# │       │   │   ├── d_lncqsmj
# │       │   │   │   ├── f_257714_dtcjv.lsd
# │       │   │   │   ├── f_69877_shzgg
# │       │   │   │   └── f_267645_vjw
# │       │   │   ├── d_mhqs
# │       │   │   │   └── f_257031_stsfrb.gvs
# │       │   │   ├── d_qfjmtvpv
# │       │   │   │   └── d_mhqs
# │       │   │   │       └── f_91378_wldhvhl
# │       │   │   ├── d_qzm
# │       │   │   │   └── d_shn
# │       │   │   │       └── d_jmmlsvdg
# │       │   │   │           └── f_41383_rnlgl.vjv
# │       │   │   ├── f_114934_shzgg.jdf
# │       │   │   └── f_187091_zpgbdnl.twq
# │       │   ├── d_hqdssf
# │       │   │   └── d_mzj
# │       │   │       └── f_169639_sgdn
# │       │   ├── f_378_rjjrg.pjq
# │       │   └── d_zjlnsztt
# │       │       └── f_78315_jfj.sgg
# │       ├── d_hqdssf
# │       │   └── f_906_rjjrg.pjq
# │       ├── d_shzgg
# │       │   └── f_163015_mhqs.cnb
# │       ├── d_vgjr
# │       │   ├── f_129546_hclg.vbl
# │       │   ├── f_286437_hqdssf
# │       │   ├── d_lncqsmj
# │       │   │   └── f_233355_fhpjbpjl.tbh
# │       │   ├── f_1552_nhgwff
# │       │   ├── f_279693_qmpdlw
# │       │   └── f_83645_slwshm.nwr
# │       └── d_wfbvtfmr
# │           ├── f_218452_jvvl.rcs
# │           ├── f_47525_rjjrg.pjq
# │           └── f_109880_tctz.rnd
# ├── d_jwphbz
# │   ├── d_bqbwds
# │   │   └── f_18049_shzgg
# │   ├── d_mwnzw
# │   │   ├── f_169353_dtqlr
# │   │   ├── d_hlrgzlph
# │   │   │   ├── f_249097_hqdssf
# │   │   │   └── f_86490_pwdmzwb
# │   │   ├── d_mhqs
# │   │   │   └── f_176337_rjjrg.pjq
# │   │   └── f_238527_vjw
# │   ├── f_113414_qgdsgfg.ngj
# │   ├── f_141013_qtp
# │   └── f_10795_slwshm.nwr
# ├── d_lncqsmj
# │   ├── d_jmsw
# │   │   ├── d_hqdssf
# │   │   │   └── f_44806_lvzm
# │   │   ├── d_nmsbdqhm
# │   │   │   ├── d_czzp
# │   │   │   │   ├── f_95330_slwshm.nwr
# │   │   │   │   └── f_82000_wfbvtfmr
# │   │   │   ├── d_gcp
# │   │   │   │   └── f_229303_ddsppspd.fcn
# │   │   │   ├── d_gsrnmq
# │   │   │   │   ├── d_hrsstlt
# │   │   │   │   │   └── f_18477_mnpc.tmh
# │   │   │   │   ├── d_rzc
# │   │   │   │   │   ├── f_33078_dmfwf
# │   │   │   │   │   ├── f_149792_wfbvtfmr.jnz
# │   │   │   │   │   └── d_zsnmz
# │   │   │   │   │       ├── d_gzsnl
# │   │   │   │   │       │   ├── f_109060_jvvl.rcs
# │   │   │   │   │       │   └── f_122307_svtppnvt.wrz
# │   │   │   │   │       ├── f_69834_lplszs.rvg
# │   │   │   │   │       ├── f_213489_slwshm.nwr
# │   │   │   │   │       └── d_vrnqh
# │   │   │   │   │           └── f_94389_jvvl.rcs
# │   │   │   │   └── f_40890_sfpt
# │   │   │   ├── d_rmngvc
# │   │   │   │   └── d_jljbrrgg
# │   │   │   │       └── f_128554_cvcbmcm
# │   │   │   ├── d_vpfq
# │   │   │   │   └── f_73628_rjjrg.pjq
# │   │   │   ├── d_vpzvb
# │   │   │   │   └── f_265609_rjjrg.pjq
# │   │   │   ├── d_wccgblsq
# │   │   │   │   └── f_110134_hffzwm.zfr
# │   │   │   └── f_43981_wfbvtfmr
# │   │   └── d_wfbvtfmr
# │   │       ├── f_209356_jvvl.rcs
# │   │       ├── f_286105_mtsb.bwd
# │   │       └── f_234687_vcgnlc.cft
# │   ├── d_mcgm
# │   │   └── f_203407_cvcbmcm
# │   ├── d_mpc
# │   │   └── d_shzgg
# │   │       └── d_bnb
# │   │           └── f_232449_lncqsmj.czs
# │   ├── f_233050_rjjrg.pjq
# │   ├── f_30757_shzgg
# │   └── f_250575_slwshm.nwr
# ├── d_mhqs
# │   └── f_116955_jvvl.rcs
# ├── d_trwqgzsb
# │   └── f_88439_jgphdrnq
# ├── f_132067_vjw
# └── d_wbsph
#     ├── d_mhqs
#     │   └── f_133965_rfh.zdb
#     └── d_vgh
#         └── f_36092_rjjrg.pjq
# Part 1 2031851
# Part 2 2568781

# %%
import unittest

class TestNotebook(unittest.TestCase):
    a = Node("d_a")
    b = Node("d_b")
    c = Node("f_5_c")
    d = Node("f_15_d")
    e = Node("f_100000_e")

    def setUp(self):
        global root, pwd
        root = Node("/")
        pwd = root
        self.a = Node("d_a")
        self.b = Node("d_b")
        self.c = Node("f_5_c")
        self.d = Node("f_15_d")
        self.e = Node("f_100000_e")
        root.children = [self.a, self.b]
        self.c.parent = self.b
        self.d.parent = self.b
        self.e.parent = self.a
    
    def test_execute_cd(self):
        global root, pwd
        self.assertEqual(root, pwd)
        execute_cd("$ cd a")
        self.assertEqual(pwd, self.a)

    def test_is_file_line(self):
        self.assertTrue(is_file_line("123 a"))
        self.assertTrue(is_file_line("1 b"))
        self.assertFalse(is_file_line("$ ls"))
        self.assertFalse(is_file_line("dir abc"))
    
    def test_get_node_size(self):
        global root
        self.assertEqual(20, get_node_size(self.b))
        self.assertEqual(100000, get_node_size(self.a))
        self.assertEqual(100020, get_node_size(root))

unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_execute_cd (__main__.TestNotebook) ... ok
# test_get_node_size (__main__.TestNotebook) ... ok
# test_is_file_line (__main__.TestNotebook) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.002s
#
# OK
